# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# %%
df = pd.read_csv('IPL_Matches_2022.csv')
df.head()
# Out:
#         ID       City        Date  MatchNumber                        Team1  \
# 0  1312200  Ahmedabad  29-05-2022        Final             Rajasthan Royals
# 1  1312199  Ahmedabad  27-05-2022  Qualifier 2  Royal Challengers Bangalore
# 2  1312198    Kolkata  25-05-2022   Eliminator  Royal Challengers Bangalore
# 3  1312197    Kolkata  24-05-2022  Qualifier 1             Rajasthan Royals
# 4  1304116     Mumbai  22-05-2022           70          Sunrisers Hyderabad
#
#                   Team2                             Venue  \
# 0        Gujarat Titans  Narendra Modi Stadium, Ahmedabad
# 1      Rajasthan Royals  Narendra Modi Stadium, Ahmedabad
# 2  Lucknow Super Giants             Eden Gardens, Kolkata
# 3        Gujarat Titans             Eden Gardens, Kolkata
# 4          Punjab Kings          Wankhede Stadium, Mumbai
#
#              TossWinner TossDecision                  WinningTeam    WonBy  \
# 0      Rajasthan Royals          bat               Gujarat Titans  Wickets
# 1      Rajasthan Royals        field             Rajasthan Royals  Wickets
# 2  Lucknow Super Giants        field  Royal Challengers Bangalore     Runs
# 3        Gujarat Titans        field               Gujarat Titans  Wickets
# 4   Sunrisers Hyderabad          bat                 Punjab Kings  Wickets
#
#    Margin Player_of_Match                                       Team1Players  \
# 0       7       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1       7      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      14      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       7       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4       5   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
# Check for duplicate rows
duplicate_rows = df[df.duplicated()]

duplicate_rows
# Out:
# Empty DataFrame
# Columns: [ID, City, Date, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, WinningTeam, WonBy, Margin, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2]
# Index: []

# %%
df.isnull().sum()
# Out:
# ID                 0
# City               0
# Date               0
# MatchNumber        0
# Team1              0
# Team2              0
# Venue              0
# TossWinner         0
# TossDecision       0
# WinningTeam        0
# WonBy              0
# Margin             0
# Player_of_Match    0
# Team1Players       0
# Team2Players       0
# Umpire1            0
# Umpire2            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               74 non-null     int64
#  1   City             74 non-null     object
#  2   Date             74 non-null     object
#  3   MatchNumber      74 non-null     object
#  4   Team1            74 non-null     object
#  5   Team2            74 non-null     object
#  6   Venue            74 non-null     object
#  7   TossWinner       74 non-null     object
#  8   TossDecision     74 non-null     object
#  9   WinningTeam      74 non-null     object
#  10  WonBy            74 non-null     object
#  11  Margin           74 non-null     int64
#  12  Player_of_Match  74 non-null     object
#  13  Team1Players     74 non-null     object
#  14  Team2Players     74 non-null     object
#  15  Umpire1          74 non-null     object
#  16  Umpire2          74 non-null     object
# dtypes: int64(2), object(15)
# memory usage: 10.0+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

# %%
df
# Out:
#          ID       City       Date  MatchNumber                        Team1  \
# 0   1312200  Ahmedabad 2022-05-29        Final             Rajasthan Royals
# 1   1312199  Ahmedabad 2022-05-27  Qualifier 2  Royal Challengers Bangalore
# 2   1312198    Kolkata 2022-05-25   Eliminator  Royal Challengers Bangalore
# 3   1312197    Kolkata 2022-05-24  Qualifier 1             Rajasthan Royals
# 4   1304116     Mumbai 2022-05-22           70          Sunrisers Hyderabad
# ..      ...        ...        ...          ...                          ...
# 69  1304051       Pune 2022-03-29            5             Rajasthan Royals
# 70  1304050     Mumbai 2022-03-28            4         Lucknow Super Giants
# 71  1304049     Mumbai 2022-03-27            3  Royal Challengers Bangalore
# 72  1304048     Mumbai 2022-03-27            2               Mumbai Indians
# 73  1304047     Mumbai 2022-03-26            1          Chennai Super Kings
#
#                     Team2                                          Venue  \
# 0          Gujarat Titans               Narendra Modi Stadium, Ahmedabad
# 1        Rajasthan Royals               Narendra Modi Stadium, Ahmedabad
# 2    Lucknow Super Giants                          Eden Gardens, Kolkata
# 3          Gujarat Titans                          Eden Gardens, Kolkata
# 4            Punjab Kings                       Wankhede Stadium, Mumbai
# ..                    ...                                            ...
# 69    Sunrisers Hyderabad  Maharashtra Cricket Association Stadium, Pune
# 70         Gujarat Titans                       Wankhede Stadium, Mumbai
# 71           Punjab Kings             Dr DY Patil Sports Academy, Mumbai
# 72         Delhi Capitals                      Brabourne Stadium, Mumbai
# 73  Kolkata Knight Riders                       Wankhede Stadium, Mumbai
#
#                TossWinner TossDecision                  WinningTeam    WonBy  \
# 0        Rajasthan Royals          bat               Gujarat Titans  Wickets
# 1        Rajasthan Royals        field             Rajasthan Royals  Wickets
# 2    Lucknow Super Giants        field  Royal Challengers Bangalore     Runs
# 3          Gujarat Titans        field               Gujarat Titans  Wickets
# 4     Sunrisers Hyderabad          bat                 Punjab Kings  Wickets
# ..                    ...          ...                          ...      ...
# 69    Sunrisers Hyderabad        field             Rajasthan Royals     Runs
# 70         Gujarat Titans        field               Gujarat Titans  Wickets
# 71           Punjab Kings        field                 Punjab Kings  Wickets
# 72         Delhi Capitals        field               Delhi Capitals  Wickets
# 73  Kolkata Knight Riders        field        Kolkata Knight Riders  Wickets
#
#     Margin Player_of_Match                                       Team1Players  \
# 0        7       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1        7      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2       14      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3        7       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4        5   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..     ...             ...                                                ...
# 69      61       SV Samson  ['JC Buttler', 'YBK Jaiswal', 'SV Samson', 'D ...
# 70       5  Mohammed Shami  ['KL Rahul', 'Q de Kock', 'E Lewis', 'MK Pande...
# 71       5        OF Smith  ['F du Plessis', 'Anuj Rawat', 'V Kohli', 'KD ...
# 72       4   Kuldeep Yadav  ['RG Sharma', 'Ishan Kishan', 'Anmolpreet Sing...
# 73       6        UT Yadav  ['RD Gaikwad', 'DP Conway', 'RV Uthappa', 'AT ...
#
#                                          Team2Players        Umpire1  \
# 0   ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1   ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2   ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3   ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4   ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                ...            ...
# 69  ['KS Williamson', 'Abhishek Sharma', 'RA Tripa...   BNJ Oxenford
# 70  ['Shubman Gill', 'MS Wade', 'V Shankar', 'HH P...      PG Pathak
# 71  ['MA Agarwal', 'S Dhawan', 'PBB Rajapaksa', 'L...    Nitin Menon
# 72  ['PP Shaw', 'TL Seifert', 'Mandeep Singh', 'RR...      RJ Tucker
# 73  ['AM Rahane', 'VR Iyer', 'N Rana', 'SS Iyer', ...   AK Chaudhary
#
#           Umpire2
# 0     Nitin Menon
# 1     Nitin Menon
# 2        MA Gough
# 3       VK Sharma
# 4   NA Patwardhan
# ..            ...
# 69      UV Gandhe
# 70      VK Sharma
# 71       YC Barde
# 72     HAS Khalid
# 73    Nitin Menon
#
# [74 rows x 17 columns]

# %%
print("Total Matches:", df.shape[0])
# Out:
# Total Matches: 74

# %%
print("Teams:", pd.unique(df[['Team1', 'Team2']].values.ravel()))
# Out:
# Teams: ['Rajasthan Royals' 'Gujarat Titans' 'Royal Challengers Bangalore'
#  'Lucknow Super Giants' 'Sunrisers Hyderabad' 'Punjab Kings'
#  'Delhi Capitals' 'Mumbai Indians' 'Chennai Super Kings'
#  'Kolkata Knight Riders']

# %%
print("Columns:", df.columns)
# Out:
# Columns: Index(['ID', 'City', 'Date', 'MatchNumber', 'Team1', 'Team2', 'Venue',
#        'TossWinner', 'TossDecision', 'WinningTeam', 'WonBy', 'Margin',
#        'Player_of_Match', 'Team1Players', 'Team2Players', 'Umpire1',
#        'Umpire2'],
#       dtype='object')
